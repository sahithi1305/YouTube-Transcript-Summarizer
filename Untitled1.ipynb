# %% [markdown]
# <a href="https://colab.research.google.com/github/sahithi1305/YouTube-Transcript-Summarizer/blob/main/Untitled1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install -q transformers

# %%
# !pip install -q youtube_transcript_api

# %%
from transformers import pipeline
from youtube_transcript_api import YouTubeTranscriptApi

# %%
youtube_video = "https://www.youtube.com/watch?v=9RhWXPcKBI8"

# %%
video_id = youtube_video.split("=")[1]

# %%
video_id
# Out:
# '9RhWXPcKBI8'

# %%
from IPython.display import YouTubeVideo
YouTubeVideo(video_id)

# %%
YouTubeTranscriptApi.get_transcript(video_id)
transcript = YouTubeTranscriptApi.get_transcript(video_id)

# %%
transcript[0:5]
# Out:
# [{'text': "I've built a massive\nisolation chamber",
#   'start': 0.1,
#   'duration': 2.369},
#  {'text': "and we're going to see\nif these two strangers",
#   'start': 3.703,
#   'duration': 2.369},
#  {'text': 'can survive in this cube\nfor the next 100 days.',
#   'start': 6.072,
#   'duration': 3.47},
#  {'text': 'They have never met each other ever.',
#   'start': 9.542,
#   'duration': 2.136},
#  {'text': 'Bailey. This is Suzie.', 'start': 11.678, 'duration': 1.802}]

# %%
result = ""
for i in transcript:
    result += ' ' + i['text']
#print(result)
print(len(result))
# Out:
# 26707

# %%
summarizer = pipeline('summarization')
# Out:
# No model was supplied, defaulted to sshleifer/distilbart-cnn-12-6 and revision a4f8f3e (https://huggingface.co/sshleifer/distilbart-cnn-12-6).
# Using a pipeline without specifying a model name and revision in production is not recommended.
# config.json:   0%|          | 0.00/1.80k [00:00<?, ?B/s]
# pytorch_model.bin:   0%|          | 0.00/1.22G [00:00<?, ?B/s]
# tokenizer_config.json:   0%|          | 0.00/26.0 [00:00<?, ?B/s]
# vocab.json:   0%|          | 0.00/899k [00:00<?, ?B/s]
# merges.txt:   0%|          | 0.00/456k [00:00<?, ?B/s]

# %%
num_iters = int(len(result)/1000)
summarized_text = []
for i in range(0, num_iters + 1):
  start = 0
  start = i * 1000
  end = (i + 1) * 1000
  print("input text \n" + result[start:end])
  out = summarizer(result[start:end])
  out = out[0]
  out = out['summary_text']
  print("Summarized text\n"+out)
  summarized_text.append(out)

print(summarized_text)
# Out:
# input text
#  I've built a massive
# isolation chamber and we're going to see
# if these two strangers can survive in this cube
# for the next 100 days. They have never met each other ever. Bailey. This is Suzie. - Suzie, this is Bailey.
# - Nice to meet you. Hi! Nice to meet you. If the two of you can survive
# the next 100 days in here. I will give you the half a million
# dollars inside of this vault. But if one of you leaves before the 100
# days is up, you both get nothing. All right. I think you
# guys understand the rules. - Have fun.
# - Okay. Bye. This is going to be crazy. Yeah. This is actually like an insane
# asylum. They're currently looking at all
# the stuff we put in there. We gave them enough food
# for 100 days, which is healthy,
# but basically the exact same thing over and over again. We also gave them their own private bathroom,
# which comes with the shower and obviously has no cameras inside
# and a bed to sleep on. They have everything
# ...

# %%
len(str(summarized_text))
# Out:
# 8407

# %%
str(summarized_text)
# Out:
# '[\' Two strangers have never met each other ever in a massive isolation chamber . If they can survive the next 100 days, Bailey will give them half a million dollars . Bailey: "This is actually like an insane psychiatric asylum. They\\\'re currently looking at all the stuff we put in there. They have everything they need to survive"\', \' Suzie and Bailey started their experiment at 2:37 a.m. on their second day after only sleeping for 2 hours . Suzie: "I just keep thinking of the feeling like exiting. Oh, yeah? How good is that going to feel? It\\\'s only a 100 sleeps. Only 100 sleeps"\', \' Time in the chamber consisted of two things trying to hide from the bright light. The lights are just so bright, they have to make these things to shield themselves. And desperate attempts to keep themselves entertained. Like on day four, when they use the paper from their journals to make a deck of playing cards.\', " It\'s crazy to me that already on day 9 of this challenge, they\'re already 
# ...
